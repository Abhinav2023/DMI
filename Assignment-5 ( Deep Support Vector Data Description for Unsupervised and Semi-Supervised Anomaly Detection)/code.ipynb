# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import numpy as np

# %%
def create_semisupervised_setting(labels, normal_classes, outlier_classes, known_outlier_classes,ratio_known_normal, ratio_known_outlier, ratio_pollution):
    """
    Create a semi-supervised data setting. 
    :param labels: np.array with labels of all dataset samples
    :param normal_classes: tuple with normal class labels
    :param outlier_classes: tuple with anomaly class labels
    :param known_outlier_classes: tuple with known (labeled) anomaly class labels
    :param ratio_known_normal: the desired ratio of known (labeled) normal samples
    :param ratio_known_outlier: the desired ratio of known (labeled) anomalous samples
    :param ratio_pollution: the desired pollution ratio of the unlabeled data with unknown (unlabeled) anomalies.
    :return: tuple with list of sample indices, list of original labels, and list of semi-supervised labels
    """
    idx_normal = np.argwhere(np.isin(labels, normal_classes)).flatten()
    idx_outlier = np.argwhere(np.isin(labels, outlier_classes)).flatten()
    idx_known_outlier_candidates = np.argwhere(np.isin(labels, known_outlier_classes)).flatten()

    n_normal = len(idx_normal)

    # Solve system of linear equations to obtain respective number of samples
    a = np.array([[1, 1, 0, 0],
                  [(1-ratio_known_normal), -ratio_known_normal, -ratio_known_normal, -ratio_known_normal],
                  [-ratio_known_outlier, -ratio_known_outlier, -ratio_known_outlier, (1-ratio_known_outlier)],
                  [0, -ratio_pollution, (1-ratio_pollution), 0]])
    b = np.array([n_normal, 0, 0, 0])
    x = np.linalg.solve(a, b)

    # Get number of samples
    n_known_normal = int(x[0])
    n_unlabeled_normal = int(x[1])
    n_unlabeled_outlier = int(x[2])
    n_known_outlier = int(x[3])

    # Sample indices
    perm_normal = np.random.permutation(n_normal)
    perm_outlier = np.random.permutation(len(idx_outlier))
    perm_known_outlier = np.random.permutation(len(idx_known_outlier_candidates))

    idx_known_normal = idx_normal[perm_normal[:n_known_normal]].tolist()
    idx_unlabeled_normal = idx_normal[perm_normal[n_known_normal:n_known_normal+n_unlabeled_normal]].tolist()
    idx_unlabeled_outlier = idx_outlier[perm_outlier[:n_unlabeled_outlier]].tolist()
    idx_known_outlier = idx_known_outlier_candidates[perm_known_outlier[:n_known_outlier]].tolist()

    # Get original class labels
    labels_known_normal = labels[idx_known_normal].tolist()
    labels_unlabeled_normal = labels[idx_unlabeled_normal].tolist()
    labels_unlabeled_outlier = labels[idx_unlabeled_outlier].tolist()
    labels_known_outlier = labels[idx_known_outlier].tolist()

    # Get semi-supervised setting labels
    semi_labels_known_normal = np.ones(n_known_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_normal = np.zeros(n_unlabeled_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_outlier = np.zeros(n_unlabeled_outlier).astype(np.int32).tolist()
    semi_labels_known_outlier = (-np.ones(n_known_outlier).astype(np.int32)).tolist()

    # Create final lists
    list_idx = idx_known_normal + idx_unlabeled_normal + idx_unlabeled_outlier + idx_known_outlier
    list_labels = labels_known_normal + labels_unlabeled_normal + labels_unlabeled_outlier + labels_known_outlier
    list_semi_labels = (semi_labels_known_normal + semi_labels_unlabeled_normal + semi_labels_unlabeled_outlier
                        + semi_labels_known_outlier)

    return list_idx, list_labels, list_semi_labels
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)


def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    mean = torch.mean(x)  # mean over all features (pixels) per sample
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %%
from torchvision.datasets import MNIST
class MyMNIST(MNIST):
    """
    Torchvision MNIST class with additional targets for the semi-supervised setting and patch of __getitem__ method
    to also return the semi-supervised target as well as the index of a data sample.
    """

    def __init__(self, *args, **kwargs):
        super(MyMNIST, self).__init__(*args, **kwargs)

        self.semi_targets = torch.zeros_like(self.targets)

    def __getitem__(self, index):
        """Override the original method of the MNIST class.
        Args:
            index (int): Index

        Returns:
            tuple: (image, target, semi_target, index)
        """
        img, target, semi_target = self.data[index], int(self.targets[index]), int(self.semi_targets[index])

        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target, semi_target, index

# %%
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import Subset
from PIL import Image

def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    """get dataloders"""
    n_classes = 2  # 0: normal, 1: outlier
    normal_classes = tuple([args.normal_class])
    outlier_classes = list(range(0, 10))
    outlier_classes.remove(args.normal_class)
    outlier_classes = tuple(outlier_classes)

    if args.n_known_outlier_classes == 0:
        known_outlier_classes = ()
    elif args.n_known_outlier_classes == 1:
        known_outlier_classes = tuple([args.known_outlier_class])
    else:
        known_outlier_classes = tuple(random.sample(outlier_classes, args.n_known_outlier_classes))
    
    transform = transforms.ToTensor()
    target_transform = transforms.Lambda(lambda x: int(x in outlier_classes))
    
    train = MyMNIST(root=data_dir, train=True,transform=transform, target_transform=target_transform,download=True)
    idx, _, semi_targets = create_semisupervised_setting(train.targets.cpu().data.numpy(), normal_classes,
                                                             outlier_classes, known_outlier_classes,
                                                             args.ratio_known_normal, args.ratio_known_outlier, args.ratio_pollution)
    train.semi_targets[idx] = torch.tensor(semi_targets)
    train = Subset(train, idx)          
    dataloader_train = DataLoader(train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    test = MyMNIST(root=data_dir, train=False, transform=transform, target_transform=target_transform,
                                download=True)
    dataloader_test = DataLoader(test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

# %%
# !pip install barbar
# Out:
# Collecting barbar
#   Downloading https://files.pythonhosted.org/packages/48/1f/9b69ce144f484cfa00feb09fa752139658961de6303ea592487738d0b53c/barbar-0.2.1-py3-none-any.whl
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1

# %%
import torch.nn as nn
import torch.nn.functional as F
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)


class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat

# %%
from torch import optim
import torch.nn.functional as F

import numpy as np
from barbar import Bar



class TrainerDeepSAD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SAD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _, _, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSAD(ae, self.train_loader) 
    

    def save_weights_for_DeepSAD(self, model, dataloader):
        """Initialize Deep SAD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _, _, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SAD model"""
        net = network().to(self.device)
        eta=1
        eps=1e-6
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _, sy, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                sy=sy.float().to(self.device)
                optimizer.zero_grad()
                z = net(x)
                dist = torch.sum((z-c) ** 2, dim=1)
                losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
                loss = torch.mean(losses)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SAD... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

# %%
from sklearn.metrics import roc_auc_score


def eval(net, c, dataloader, device):
    """Testing the Deep SAD model"""

    scores = []
    labels = []
    epoch_loss=0
    nb=0
    eta=1.0
    eps=1e-6
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y, sy,_ in dataloader:
            x = x.float().to(device)
            y = y.float().to(device)
            sy= sy.float().to(device)
            z = net(x)
            dist = torch.sum((z-c) ** 2, dim=1)
            losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
            loss = torch.mean(losses)
            score=dist
            scores.append(score.detach().cpu())
            labels.append(y.cpu())
            epoch_loss+=loss
            nb+=1
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    print('mean loss: {:.2f}'.format(epoch_loss/nb))
    return labels, scores

# %%
class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass
    self.ratio_known_outlier=0.01
    self.ratio_known_normal=0.0
    self.ratio_pollution=0.1
    self.known_outlier_class=(nclass+1)%10
    self.n_known_outlier_classes=1

# %%
import matplotlib.pyplot as plt
import pandas as pd
nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SAD = TrainerDeepSAD(args, data, device)
  if args.pretrain:
      deep_SAD.pretrain()
  deep_SAD.train()
  print("test for calss  ",i,".....")
  labels, scores = eval(deep_SAD.net, deep_SAD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 141.107
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 107.910
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 88.344
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 76.434
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 68.329
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 62.370
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 57.885
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 54.684
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 52.273
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 50.243
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.566
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 47.097
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.900
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 44.798
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 43.853
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 42.969
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 42.128
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 41.346
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 40.594
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 39.822
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.433
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.197
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.127
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.096
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.079
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.070
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.063
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.056
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.052
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.049
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.047
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.045
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.042
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.041
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.041
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.042
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.039
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.038
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.037
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.035
# test for calss   0 .....
# Testing...
# ROC AUC score: 95.25
# mean loss: 0.13
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 178.284
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 137.516
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 102.936
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 78.437
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 62.652
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 52.480
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 45.514
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 40.484
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 36.733
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 33.783
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 31.438
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 29.662
# 7566/7566: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 12, Loss: 28.227
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 27.048
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 26.062
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 25.225
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 24.490
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 23.860
# 7566/7566: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 18, Loss: 23.294
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 22.788
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.419
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.156
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.099
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.082
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.072
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.066
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.061
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.058
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.057
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.053
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.051
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.050
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.049
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.047
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.046
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.045
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.043
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.043
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.042
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.041
# test for calss   1 .....
# Testing...
# ROC AUC score: 98.63
# mean loss: 0.13
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 171.334
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 138.700
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 107.159
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 86.404
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 73.583
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 65.531
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 60.076
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 56.181
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 53.224
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 50.827
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.868
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 47.211
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.754
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 44.487
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 43.334
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 42.348
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 41.460
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 40.705
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 40.033
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 39.398
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.519
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.247
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.173
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.142
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.123
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.109
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.099
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.092
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.088
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.082
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.078
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.074
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.071
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.069
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.066
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.064
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.062
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.060
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.059
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.057
# test for calss   2 .....
# Testing...
# ROC AUC score: 87.10
# mean loss: 0.11
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 139.046
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 105.370
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 85.244
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 72.443
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 64.326
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 58.822
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 54.760
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 51.596
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 49.245
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 47.364
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 45.850
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.617
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 43.527
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.611
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 41.766
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 41.056
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 40.388
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 39.779
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 39.203
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 38.620
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.400
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.191
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.133
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.109
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.095
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.086
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.080
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.074
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.071
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.067
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.063
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.060
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.059
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.056
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.054
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.053
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.052
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.051
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.048
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.047
# test for calss   3 .....
# Testing...
# ROC AUC score: 88.27
# mean loss: 0.12
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 180.938
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 144.564
# 6556/6556: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 2, Loss: 116.807
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 95.958
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 80.947
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 70.499
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 63.080
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 57.656
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 53.569
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 50.385
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 47.827
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 45.716
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 43.923
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 42.402
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 41.099
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.969
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 38.959
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 38.042
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 37.214
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 36.442
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.577
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.241
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.162
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.130
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.114
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.102
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.095
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.088
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.082
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.078
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.075
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.070
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.068
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.066
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.064
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.062
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.060
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.059
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.058
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.056
# test for calss   4 .....
# Testing...
# ROC AUC score: 92.78
# mean loss: 0.14
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 172.449
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 138.845
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 112.327
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 93.019
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 79.869
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 71.010
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 64.805
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 60.105
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 56.482
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 53.589
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 51.234
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 49.235
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 47.533
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 46.099
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 44.712
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 43.588
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 42.587
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 41.709
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 40.889
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 40.160
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.656
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.265
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.175
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.143
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.127
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.116
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.105
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.100
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.092
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.090
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.085
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.081
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.077
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.077
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.073
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.072
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.072
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.067
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.065
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.063
# test for calss   5 .....
# Testing...
# ROC AUC score: 80.91
# mean loss: 0.10
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 128.497
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 97.046
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 78.301
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 67.261
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 60.335
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 55.501
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 51.773
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 48.851
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 46.415
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 44.301
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 42.773
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 41.467
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 40.367
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 39.431
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 38.617
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 37.858
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 37.196
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 36.616
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 36.077
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 35.577
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.656
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.279
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.172
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.129
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.106
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.094
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.084
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.080
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.071
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.067
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.064
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.062
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.061
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.058
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.055
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.054
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.053
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.052
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.050
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.049
# test for calss   6 .....
# Testing...
# ROC AUC score: 96.51
# mean loss: 0.13
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 149.789
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 113.905
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 89.738
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 74.502
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 64.395
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 57.320
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 52.205
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 48.442
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 45.516
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 43.200
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 41.302
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 39.792
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 38.280
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 37.115
# 7031/7031: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 14, Loss: 36.080
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 35.190
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 34.475
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 33.613
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 32.979
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 32.336
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.524
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.225
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.139
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.107
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.091
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.082
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.074
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.070
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.067
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.066
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.061
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.058
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.055
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.056
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.055
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.052
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.051
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.052
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.048
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.051
# test for calss   7 .....
# Testing...
# ROC AUC score: 93.88
# mean loss: 0.14
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 143.934
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 107.625
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 85.700
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 73.684
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 65.864
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 60.415
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 56.555
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 53.691
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.450
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 49.655
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.142
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 46.918
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.916
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 45.058
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 44.321
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 43.675
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 43.104
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 42.591
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 42.113
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 41.670
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.520
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.236
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.160
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.132
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.118
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.108
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.099
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.094
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.088
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.083
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.079
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.076
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.073
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.071
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.069
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.067
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.065
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.063
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.062
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.061
# test for calss   8 .....
# Testing...
# ROC AUC score: 84.99
# mean loss: 0.12
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 176.295
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 139.159
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 110.826
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 90.181
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 76.429
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 67.156
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 60.623
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 55.668
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.846
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 48.860
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 46.516
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.668
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 43.146
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 41.845
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 40.714
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.701
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 38.783
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 37.941
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 37.232
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 36.571
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.447
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.180
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.113
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.094
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.082
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.075
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.069
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.065
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.063
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.061
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.059
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.056
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.055
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.053
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.051
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.050
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.049
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.048
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.047
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.046
# test for calss   9 .....
# Testing...
# ROC AUC score: 91.01
# mean loss: 0.11

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  95.24544097017966
# ROC scores for class  1  is:  98.62677310911842
# ROC scores for class  2  is:  87.09789198805053
# ROC scores for class  3  is:  88.26553155871761
# ROC scores for class  4  is:  92.78068664662078
# ROC scores for class  5  is:  80.90931985087767
# ROC scores for class  6  is:  96.5064793893863
# ROC scores for class  7  is:  93.87657190290241
# ROC scores for class  8  is:  84.99050882438186
# ROC scores for class  9  is:  91.0064783426748

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for calss '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
